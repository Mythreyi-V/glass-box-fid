# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os

os.chdir('drive/MyDrive/three-phase-fidelity-wip/diabetes/datasets')
print(os.getcwd())
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/three-phase-fidelity-wip/diabetes/datasets

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np

data = pd.read_csv("diabetes_unpro.csv")#, sep = ";")
pro_data = data.dropna()

pro_data.shape
# Out:
# (768, 9)

# %%
pro_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
num_cols = pro_data.columns.drop('Outcome')
one_hot_cols = None

col_dict = {"continuous": list(num_cols), "discrete": one_hot_cols}

# %%
pro_data.to_csv("diabetes.csv", index = False)

import json

form = json.dumps(col_dict)
f = open("col_dict.json", "w")
f.write(form)
f.close()

# %%
with open('col_dict.json') as file:
    col_dict = json.load(file)
file.close()
col_dict
# Out:
# {'continuous': ['Pregnancies',
#   'Glucose',
#   'BloodPressure',
#   'SkinThickness',
#   'Insulin',
#   'BMI',
#   'DiabetesPedigreeFunction',
#   'Age'],
#  'discrete': None}
