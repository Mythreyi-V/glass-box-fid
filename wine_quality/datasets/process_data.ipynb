# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os

os.chdir('drive/MyDrive/three-phase-fidelity-wip/wine_quality/datasets')
print(os.getcwd())
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/three-phase-fidelity-wip/wine_quality/datasets

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer
import numpy as np

df = pd.read_csv("winequality-white.csv", delimiter = ";")

target_col = 'quality'

feature_names = [col for col in df.columns if col != target_col]

#df = remove_missing_values(df)

possible_outcomes = list(df[target_col].unique())
print("Possible outcomes:", possible_outcomes)

#numerical_cols, categorical_cols, columns_type = get_columns_type(df)


#for column in data.columns:
#    data[column].replace(' ?', None, inplace=True)
pro_data = df.dropna()

non_num_cols = [column for column in pro_data.drop([target_col], axis = 1).columns if pro_data[column].dtypes == "O"]
num_cols = [column for column in pro_data.drop([target_col], axis = 1).columns if column not in non_num_cols]

num_data = pro_data[num_cols]
cat_data = pro_data[non_num_cols]
#pro_data.to_csv("car_price.csv", index = False)
# Out:
# Possible outcomes: [6, 5, 7, 8, 4, 3, 9]

# %%
pro_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
pro_data.to_csv("wine_quality.csv", index = False)

num_cols = pro_data.columns.drop('quality')
one_hot_cols = None

col_dict = {"continuous": list(num_cols), "discrete": one_hot_cols}

import json

form = json.dumps(col_dict)
f = open("col_dict.json", "w")
f.write(form)
f.close()

with open('col_dict.json') as file:
    col_dict = json.load(file)
file.close()
col_dict
# Out:
# {'continuous': ['fixed acidity',
#   'volatile acidity',
#   'citric acid',
#   'residual sugar',
#   'chlorides',
#   'free sulfur dioxide',
#   'total sulfur dioxide',
#   'density',
#   'pH',
#   'sulphates',
#   'alcohol'],
#  'discrete': None}

# %%
pro_data.shape
# Out:
# (4898, 12)

# %%
df.shape
# Out:
# (4898, 12)

# %%
pro_data[target_col].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64
